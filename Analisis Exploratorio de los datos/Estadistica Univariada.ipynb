# %% [markdown]
# # Lectura de Datos

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/XMX5634/Documents/Introduccion Ciencia de Datos Aplicada/listings.csv')

# %%
df.head(5)
# Out:
#       id                         listing_url     scrape_id last_scraped  \
# 0   2818   https://www.airbnb.com/rooms/2818  2.021040e+13   12/04/2021
# 1  20168  https://www.airbnb.com/rooms/20168  2.021040e+13   12/04/2021
# 2  25428  https://www.airbnb.com/rooms/25428  2.021040e+13   11/04/2021
# 3  27886  https://www.airbnb.com/rooms/27886  2.021040e+13   11/04/2021
# 4  28871  https://www.airbnb.com/rooms/28871  2.021040e+13   13/04/2021
#
#                                                 name  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1       Studio with private bathroom in the centre 1
# 2  Lovely, 1 bed apt in Ctr (w.lift) -3/20-6/20(f...
# 3  Romantic, stylish B&B houseboat in canal district
# 4                            Comfortable double room
#
#                                          description  \
# 0  Quiet Garden View Room & Super Fast WiFi<br />...
# 1  17th century Dutch townhouse in the heart of t...
# ...

# %%
#visualizar los primeros registros
df.head(5)
# Out:
#       id                                               name  host_id  \
# 0   2818           Quiet Garden View Room & Super Fast WiFi     3159
# 1  20168       Studio with private bathroom in the centre 1    59484
# 2  27886  Romantic, stylish B&B houseboat in canal district    97647
# 3  28871                            Comfortable double room   124245
# 4  29051                            Comfortable single room   124245
#
#    host_name  neighbourhood_group                           neighbourhood  \
# 0     Daniel                  NaN  Oostelijk Havengebied - Indische Buurt
# 1  Alexander                  NaN                            Centrum-Oost
# 2       Flip                  NaN                            Centrum-West
# 3      Edwin                  NaN                            Centrum-West
# 4      Edwin                  NaN                            Centrum-Oost
#
#    latitude  longitude     room_type  price  minimum_nights  \
# ...

# %%
#tipo de dato de cada archivo. 
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %% [markdown]
# ## Tablas de Frecuencias

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood_group               6893
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                        646
# reviews_per_month                  646
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                            444
# dtype: int64

# %%
# frecuencia absoluta
frec_abs = df['neighbourhood'].value_counts().reset_index()
frec_abs.head()
# Out:
#                      index  neighbourhood
# 0   De Baarsjes - Oud-West           1001
# 1             Centrum-West            888
# 2  De Pijp - Rivierenbuurt            710
# 3             Centrum-Oost            635
# 4               Westerpark            449

# %%
# frecuencia relativa 
frec_abs['porcentaje_neighbourhood'] = frec_abs['neighbourhood'].apply(lambda x: x/frec_abs['neighbourhood'].sum())
frec_abs
# Out:
#                                      index  neighbourhood  \
# 0                   De Baarsjes - Oud-West           1001
# 1                             Centrum-West            888
# 2                  De Pijp - Rivierenbuurt            710
# 3                             Centrum-Oost            635
# 4                               Westerpark            449
# 5                                     Zuid            428
# 6                                 Oud-Oost            371
# 7                            Bos en Lommer            308
# 8                                Oud-Noord            290
# 9                          Watergraafsmeer            248
# 10  Oostelijk Havengebied - Indische Buurt            235
# 11                              Noord-West            202
# 12                              Noord-Oost            200
# 13                IJburg - Zeeburgereiland            175
# 14                  Buitenveldert - Zuidas            143
# ...

# %%
# frecuencia absoluta y relativa acumulada con cumsum()
#absoluta acumulada 
frec_abs['acumulada_neighbourhood'] = frec_abs['neighbourhood'].cumsum()
# relativa acumulada
frec_abs['acumulada_porcentaje_neighbourhood'] = frec_abs['porcentaje_neighbourhood'].cumsum()
frec_abs
# Out:
#                                      index  neighbourhood  \
# 0                   De Baarsjes - Oud-West           1001
# 1                             Centrum-West            888
# 2                  De Pijp - Rivierenbuurt            710
# 3                             Centrum-Oost            635
# 4                               Westerpark            449
# 5                                     Zuid            428
# 6                                 Oud-Oost            371
# 7                            Bos en Lommer            308
# 8                                Oud-Noord            290
# 9                          Watergraafsmeer            248
# 10  Oostelijk Havengebied - Indische Buurt            235
# 11                              Noord-West            202
# 12                              Noord-Oost            200
# 13                IJburg - Zeeburgereiland            175
# 14                  Buitenveldert - Zuidas            143
# ...

# %%
# frecuencia bivariada 
pd.crosstab(index = df['room_type'], columns = df['neighbourhood'])
# Out:
# neighbourhood    Bijlmer-Centrum  Bijlmer-Oost  Bos en Lommer  \
# room_type
# Entire home/apt               60            20            268
# Hotel room                     0             0              1
# Private room                  34            13             39
# Shared room                    0             1              0
#
# neighbourhood    Buitenveldert - Zuidas  Centrum-Oost  Centrum-West  \
# room_type
# Entire home/apt                     105           383           458
# Hotel room                            1             9            17
# Private room                         37           239           404
# Shared room                           0             4             9
#
# neighbourhood    De Aker - Nieuw Sloten  De Baarsjes - Oud-West  \
# room_type
# Entire home/apt                      46                     812
# Hotel room                            0                      11
# Private room                         43                     177
# ...

# %% [markdown]
# ## Tendencia Central

# %%
#Media 
df['price'].mean()
# Out:
# 218.48730596257073

# %%
# Mediana 
df['price'].median()
# Out:
# 180.0

# %%
# Moda 
df['price'].mode()
# Out:
# 0    150
# dtype: int64

# %% [markdown]
# ## Medidas de Localización

# %%
df['price'].quantile([0.20,0.50,0.70])
# Out:
# 0.2    112.0
# 0.5    180.0
# 0.7    245.0
# Name: price, dtype: float64

# %% [markdown]
#  El percentil 50 tiene un valor de 180, lo cual nos indica que la mitad de los precios de hospedaje tienen un precio a lo mas de 180.

# %% [markdown]
# ## Medidas de Dispersión

# %%
# Desviacion Estandar 
df['price'].std()
# Out:
# 192.57632752720244

# %%
# Rango Intercuartilico 
df['price'].quantile(0.75) - df['price'].quantile(0.25)
# Out:
# 139.0

# %%
# Rango 
df['price'].max() - df['price'].min()
# Out:
# 7900

# %%
# Coeficiente de Variación 

df['price'].std()/ df['price'].mean()
# Out:
# 0.8814073965477558
